# %%
from PySimCore import Environment
from SimPainter.cairo_painter import SimCairoPainter
from IPython.core import display

e = Environment()
e.import_classes_from_dir('C:/Users/Nikon/PycharmProjects/SimulinkLib/SimStandardElements')
e.parse_xml('C:/Users/Nikon/PycharmProjects/SimulinkLib/sin.xml')

painter = SimCairoPainter(600, 500)
e.paint(painter)

display.Image(data=painter.get_image_as_byte_data(), format='png', embed=True)
# Out:
# MainEnvironment {}
